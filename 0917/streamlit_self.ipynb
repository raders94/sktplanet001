# %%
import pandas as pd
import plotly.express as px

PRO01_CSV_PATH = './pro01.csv'

df = pd.read_csv(PRO01_CSV_PATH, encoding='cp949') #utf-8 or cp949


df
# Out:
#         연도   월  분기 청코드 내외항구분 수출입구분명  시설코드       시설명   부두구분명 아외국구분 적공구분  \
# 0     2024   3   1  신항    외항     수입     6  신항 W 정박지    일반부두   외국선   적컨
# 1     2024   4   2  신항    외항     수입     6  신항 W 정박지    일반부두   아국선   적컨
# 2     2024  11   4  신항    외항   수입환적     7  신항 U 정박지    일반부두   아국선   공컨
# 3     2024  11   4  신항    외항     수입     7  신항 U 정박지    일반부두   아국선   공컨
# 4     2024  11   4  신항    외항   수입환적     7  신항 U 정박지    일반부두   아국선   적컨
# ...    ...  ..  ..  ..   ...    ...   ...       ...     ...   ...  ...
# 2404  2024   7   3  북항    외항   수입환적     8    자성대 부두  컨테이너부두   외국선   적컨
# 2405  2024   7   3  북항    외항     수출     8    자성대 부두  컨테이너부두   외국선   적컨
# 2406  2024   7   3  북항    외항     수입     8    자성대 부두  컨테이너부두   외국선   적컨
# 2407  2024  11   4  북항    외항     수출     8    자성대 부두  컨테이너부두   외국선   적컨
# 2408  2024  11   4  북항    외항     수입     8    자성대 부두  컨테이너부두   외국선   적컨
#
#       컨테이너수(10피트)  컨테이너수(20피트)  컨테이너수(40피트)  컨테이너수(기타)   전체개수     전체물동량
# ...

# %%
fig=px.bar(
        df,
        x='items',
        y='sales',
        title='제품별 매출'
    )

fig.show()

# %%
dx= pd.DataFrame({
        'month': ['jan','feb','mar','apr','may','jun'],
        'sales': [120,50,70,90,160,180],

    })

fig =px.line(dx,
        x='month',
        y='sales',
        markers=True,
        title='월별 매출 변화량')
fig.show()

# %%
df= pd.DataFrame({
        'month': ['jan','jan','feb','feb','mar','mar'],
        'category': [
            'pc','주변기기',
            'pc','주변기기',
            'pc','주변기기',
                     ],
        'sales': [ 120,80,75,46,13,49,]

    })

fig= px.bar(df,
            x='month',
            y='sales',
            color='category',
            barmode='group',
            title='월별 카테고리 매출')

fig.show()

# %% [markdown]
# ## 데이터 시각화 툴 비교
#
# |구분|Matplotlib|Seaborn|Plotly|
# |---|---|---|---|
# |목적|범용 그래프 작성|통계 데이터 시각화|인터렉티브 시각화|
# |웹대시보드활용|추가작업이 필요|추가작업이 덜 필요|활용용이|
# |세부제어|가장 세밀하게 제어|matplotlib을 사용|그래픽 오브젝트 활용|

# %%
df = pd.DataFrame({
    "product": [
        "노트북", "모니터", "키보드", "마우스",
        "태블릿", "헤드셋", "웹캠", "스피커",
        "SSD", "공유기", "스마트폰", "충전기",
    ],
    "category": [
        "PC", "PC", "주변기기", "주변기기",
        "모바일", "주변기기", "주변기기", "주변기기",
        "PC", "네트워크", "모바일", "모바일",
    ],
    "region": [
        "서울", "부산", "서울", "대전",
        "부산", "서울", "대전", "부산",
        "서울", "대전", "부산", "서울",
    ],
    "quantity": [
        32, 28, 45, 50,
        26, 38, 20, 24,
        35, 18, 30, 55,
    ],
    "sales": [
        320, 210, 150, 110,
        260, 140, 90, 120,
        180, 100, 360, 80,
    ],
    "profit": [
        72, 48, 41, 28,
        58, 35, 21, 26,
        46, 22, 81, 18,
    ],
    "satisfaction": [
        4.6, 4.3, 4.5, 4.2,
        4.7, 4.1, 4.0, 4.3,
        4.5, 3.9, 4.8, 4.1,
    ],
})

df
# Out:
#    product category region  quantity  sales  profit  satisfaction
# 0      노트북       PC     서울        32    320      72           4.6
# 1      모니터       PC     부산        28    210      48           4.3
# 2      키보드     주변기기     서울        45    150      41           4.5
# 3      마우스     주변기기     대전        50    110      28           4.2
# 4      태블릿      모바일     부산        26    260      58           4.7
# 5      헤드셋     주변기기     서울        38    140      35           4.1
# 6       웹캠     주변기기     대전        20     90      21           4.0
# 7      스피커     주변기기     부산        24    120      26           4.3
# 8      SSD       PC     서울        35    180      46           4.5
# 9      공유기     네트워크     대전        18    100      22           3.9
# 10    스마트폰      모바일     부산        30    360      81           4.8
# 11     충전기      모바일     서울        55     80      18           4.1
